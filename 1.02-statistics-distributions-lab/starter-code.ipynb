# %% [markdown]
# # 2.03 Distributions Lab
#
# **NOTE**: Double-click on the cells that say "Type _Markdown_ and LaTeX: $\alpha^2$" to open a Markdown cell in which you can enter text without needing to put comments in code cells!

# %% [markdown]
# #### 1. Define distribution.

# %% [markdown]
# set of values of a variable and the frequency of the observation of the variable

# %% [markdown]
# #### 2. When summarizing the distribution of a variable, what are the three aspects of distributions we want to make sure we summarize?

# %% [markdown]
# centre - mean , median , mode
# <br>
# spread - std, range
# <br>
# shape - skew, symetry

# %% [markdown]
# #### 3. What is a Bernoulli random variable?

# %% [markdown]
# one occurance of an experiment containing a variable with two possible outcomes with fixed probability of success.
# <br>
# p(outcome we want)= 1-(p) where p is a known probability

# %% [markdown]
# #### 4. What is the relationship between the Bernoulli and Binomial distributions?

# %% [markdown]
#  A binomial distribution is the collection of the probabilities associated with independent, recurring Bernoulli trials.

# %% [markdown]
# #### 5. What is the relationship between the Binomial and Poisson distributions?

# %% [markdown]
# Poisson distribution is a Binomial distribution conducted infinite amount within a given timeframe and where the probablity of success approaches 0.
# <br>
# The Poisson distribution is a time limited  case of a Binomial distribution when the number of trials, n, gets very large and p, the probability of success, is small.

# %% [markdown]
# #### 6. What is the relationship between the Exponential and Geometric distributions?

# %% [markdown]
# The latter is a sub type of the former.
# <br>
# Exponential distributions involve raising numbers to a certain power whereas geometric distributions are more general other operations on numbers.
# <br>
# Also Geometric distributions can only include integers.

# %% [markdown]
# #### 7. Let's walk through the Central Limit Theorem.
#
# a) Let's create a population of 10,000 observations from a Normal distribution with mean 500 and standard deviation 100. Save this as `population`. Before this step, however, set your seed to 45 using using `random.seed(45)`.

# %%
import numpy as np
np.random.seed(45)
population= np.random.normal(loc=500,scale=100,size=10000)

# %%
population[:-10]
# Out:
# array([502.63747728, 526.03217014, 460.48544585, ..., 569.29533961,
#        447.43683034, 409.26871453])

# %% [markdown]
# b) Generate 1,000 random samples of size 5 from `population`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `norm_samples_5`.

# %%
import scipy.stats as stats

# %%
def h_sampler(population,n,k):
    counter=0
    sample_means=[]
    while counter <= k:
        temp=np.random.choice(population,n,True)
        temp_mean=np.mean(temp)
        sample_means.append(temp_mean)
        counter+=1
    return sample_means

# %%
h_sampler(population,5,1000)
# Out:
# [510.17885851706814,
#  458.1830175316816,
#  498.18163892128007,
#  521.777979588106,
#  424.4678473818018,
#  462.29698443298304,
#  540.6939358810513,
#  485.9663861267394,
#  506.84401492699027,
#  433.68774191162083,
#  524.541055352093,
#  433.3355618198346,
#  489.42267958049933,
#  512.4339288780372,
#  531.2060307349532,
#  489.92738222601247,
#  471.48168608004363,
#  524.0200389777071,
#  558.8339385373754,
#  427.124229853864,
#  499.799133999504,
#  479.9308965949358,
#  550.2757411196413,
#  575.6804631229338,
#  490.1086772269784,
#  518.8686082361613,
#  442.2627842782475,
#  516.9374011927864,
#  482.7597536560894,
#  511.7568796660322,
#  555.4845900035946,
#  487.6562719763818,
#  566.1304483563604,
#  456.5721347626815,
#  546.4911228408864,
#  476.46477460495646,
#  526.188198386664,
#  499.05655553844247,
#  475.639007319933,
#  546.974870536951,
#  ...]

# %% [markdown]
# We simulated the sampling distribution of $\bar{X}$ when we took the mean of 1,000 samples from the population. This isn't exactly what the sampling distribution of $\bar{X}$ is, but it's close enough for our purposes!
#
# (In general, we'd actually take every possible sample of size 5 from our population, but that can get really complicated.)

# %% [markdown]
# c) Plot `norm_samples_5` **with** a kernel density estimate using `seaborn.distplot`.

# %%
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
sns.distplot(norm_samples_5)

# %% [markdown]
# d) How would you describe the shape of the distribution from c)?

# %% [markdown]
# Normal distribution

# %% [markdown]
# e) Generate 1,000 random samples of size 50 from `population`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `norm_samples_50`.

# %%
def sampler(population, n=30, k=1000):
    sample_means = []
    for i in range(k):
        sample = np.random.choice(population, size=n, replace=True)
        sample_means.append(np.mean(sample))
    return sample_means

# %%
stats.describe(population)
# Out:
# DescribeResult(nobs=10000, minmax=(157.5372678572383, 877.2363776473086), mean=499.7285447782048, variance=9904.248976260284, skewness=0.01565381242883787, kurtosis=-0.037275580161021615)

# %%
norm_samples_50=sampler(population,50,1000)

# %%
norm_samples_50
# Out:
# [487.3574214949594,
#  506.8134865784269,
#  516.3748720518038,
#  503.0920772038301,
#  484.57480079923704,
#  454.6724722980909,
#  506.2830389868043,
#  504.0858926707182,
#  507.7630692336716,
#  522.9507074997086,
#  512.8636863167362,
#  494.185204240297,
#  508.1686151247481,
#  521.5832948015338,
#  495.73761835638106,
#  491.24577876422745,
#  464.87707343847376,
#  511.9731022067935,
#  501.7828619595821,
#  523.161548049757,
#  530.4220046353479,
#  465.4885448651564,
#  513.1736470125733,
#  487.63072899434076,
#  487.66892806856004,
#  489.30264274982915,
#  494.4990805478715,
#  515.5287553701551,
#  505.4510351683168,
#  509.89564604059416,
#  482.61386726042997,
#  502.8628021072151,
#  507.44728135279263,
#  476.18551187608506,
#  528.1722827258051,
#  482.3930307546964,
#  482.70546480749925,
#  513.4851318489902,
#  480.7637693452699,
#  484.50484327414387,
#  480.7577601764609,
#  522.158887353211,
#  501.80604160475787,
#  515.4933662366603,
#  495.8425922986602,
#  503.20257057452903,
#  489.045394574444,
#  508.07186430614587,
#  482.50483812535435,
#  481.1955828080587,
#  474.2257204007058,
#  502.0890861647756,
#  478.38020237384893,
#  498.88286355773556,
#  473.7911958176451,
#  504.7876481039777,
#  502.78233327879616,
#  513.6993178238829,
#  475.84991479120094,
#  491.7881578587044,
#  522.7655404807904,
#  470.7317030233262,
#  492.421863218967,
#  503.6653448707203,
#  475.0359368296343,
#  515.602470354464,
#  507.2571334898114,
#  498.82112689585983,
#  509.555380100435,
#  506.1800326364589,
#  490.30527648926886,
#  489.9415239132681,
#  535.4811548987379,
#  502.21301839720707,
#  509.7472775904088,
#  516.8768421237223,
#  490.62285807646595,
#  513.2254598242364,
#  486.9057072883012,
#  538.0903930466935,
#  500.33442863703766,
#  499.8013319671916,
#  498.4784865770973,
#  507.9807234331246,
#  480.2485450402946,
#  503.5071622730184,
#  505.3455722433421,
#  516.3804257115061,
#  479.78199045919473,
#  494.7761582586394,
#  495.75615242484696,
#  509.84691921605156,
#  499.9587003636098,
#  482.1365843652052,
#  507.4214764265708,
#  479.72333538547895,
#  504.03233049880146,
#  489.829493242576,
#  483.14061608745146,
#  509.484541203339,
#  495.46645442640596,
#  529.0310218643544,
#  493.7604281576488,
#  484.54299547041063,
#  493.3258754039214,
#  482.2416907568485,
#  511.87631940213106,
#  494.4025876619258,
#  471.9482425183277,
#  495.5371147690901,
#  500.73009661175774,
#  532.2418957943612,
#  518.6544594077442,
#  505.4537988668363,
#  516.0624861678974,
#  484.3943290378873,
#  515.7991623368404,
#  501.2308333218469,
#  497.0149606305417,
#  506.02256669098927,
#  525.2613456488459,
#  490.5182113577557,
#  533.1169531601776,
#  516.8370468251371,
#  522.1651428916488,
#  500.24261432361556,
#  492.93371582708573,
#  523.5297259183103,
#  503.7518218665739,
#  500.5566155514878,
#  477.1800032875534,
#  493.0781960744731,
#  526.4997549792605,
#  499.0752693928636,
#  495.5022108585194,
#  522.6491452783416,
#  496.4058497586183,
#  511.34896426933426,
#  504.7404326806383,
#  503.6680783016464,
#  501.8697864708548,
#  502.25799157485073,
#  494.8919675977876,
#  479.34763941520055,
#  484.999903903656,
#  498.2167647114071,
#  516.0560468742738,
#  525.1087013542524,
#  491.0145364352295,
#  499.8327881788444,
#  487.0951310257947,
#  503.29061269126265,
#  522.8113176590709,
#  514.8139143591246,
#  499.16577730282194,
#  503.93674573924545,
#  506.0461673851098,
#  491.7004296940686,
#  477.8984963901902,
#  508.36230832391243,
#  497.6809244204867,
#  496.8816588164562,
#  482.67302851761224,
#  487.7981439153132,
#  522.2909148945265,
#  485.1699281496801,
#  507.579756734119,
#  493.99283196996066,
#  491.96142686060784,
#  466.16406257580854,
#  506.5819104754144,
#  501.79277862272,
#  490.2208435252841,
#  479.34159603481584,
#  494.03173913996807,
#  506.2066042329914,
#  491.11440729747324]

# %% [markdown]
# f) Plot `norm_samples_50` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(norm_samples_50);

# %% [markdown]
# g) How would you describe the shape of the distribution from f), relative to the distribution you generated for part c)?

# %%
np.random.exponential(5)
# Out:
# 7.564242383768508

# %% [markdown]
# Lower spread, standard deviation seems lower

# %% [markdown]
# h) Run this command:
#
# ```python
# random.seed(46)
# population_2 = [np.random.choice([np.random.poisson(2),np.random.poisson(10),np.random.exponential(5)]) for i in range(10000)]
#
# ```

# %%
np.random.seed(46)
population_2 = [np.random.choice([np.random.poisson(2),np.random.poisson(10),np.random.exponential(5)]) for i in range(10000)]

# %% [markdown]
# i) What is the command in h) doing?

# %%
stats.describe(population_2)
# Out:
# DescribeResult(nobs=10000, minmax=(0.0, 34.77134631179777), mean=5.604899871636421, variance=22.776863573264702, skewness=0.9729642884694579, kurtosis=0.8317993040871898)

# %% [markdown]
# creates a list called population_2 with 1000  of the a

# %% [markdown]
# j) Is the population created in `population_2` Normally distributed? How do you know?

# %% [markdown]
# skew and the kurtosis is close to zero so the distribution is normal

# %% [markdown]
# k) Generate 1,000 random samples of size 5 from `population_2`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `poiexp_samples_5`.

# %%
poiexp_samples_5=sampler(population_2,5,1000)

# %% [markdown]
# l) Plot `poiexp_samples_5` **with** a kernel density estimate using `seaborn.distplot`.

# %%
sns.distplot(poiexp_samples_5);

# %% [markdown]
# m) How would you describe the shape of the distribution from l)?

# %% [markdown]
# Right skewed

# %%
stats.describe(poiexp_samples_5)
# Out:
# DescribeResult(nobs=1000, minmax=(0.8054283914717019, 14.257390365875102), mean=5.518293672306626, variance=4.476867376767358, skewness=0.42378076114720753, kurtosis=0.11676296174062717)

# %% [markdown]
# n) Generate 1,000 random samples of size 50 from `population_2`. Calculate the mean of each of these samples (so you should have 1,000 means) and put them in a list `poiexp_samples_50`.

# %%
poiexp_samples_50=sampler(population_2,50,1000)

# %% [markdown]
# o) Plot `poiexp_samples_50` with a kernel density estimate using seaborn.distplot.

# %%
sns.distplot(poiexp_samples_50);

# %% [markdown]
# p) How would you describe the shape of the distribution from o)?

# %% [markdown]
# approaching normal destribution

# %%
stats.describe(poiexp_samples_50)
# Out:
# DescribeResult(nobs=1000, minmax=(2.9897268811847346, 8.429194192231824), mean=5.554351836514808, variance=0.45249424311393727, skewness=0.18549252397752428, kurtosis=0.35150949596890824)

# %% [markdown]
# **You just observed the Central Limit Theorem. Let's make this a bit more explicit.**
#
# q) When our original data came from a Normal distribution (`population`) and we looked at the sampling distribution of $\bar{X}$ for $n=5$ (`norm_samples_5`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# not normal

# %% [markdown]
# r) When our original data came from a Normal distribution (`population`) and we looked at the sampling distribution of $\bar{X}$ for $n=50$ (`norm_samples_50`), what was the shape of the sampling distribution of $\bar{X}$?

# %%
approaching normal

# %% [markdown]
# s) So, if our original population is a Normal distribution, what will the sampling distribution be shaped like - regardless of sample size?

# %% [markdown]
# normal

# %% [markdown]
# t) When our original data came from a non-Normal distribution (`population_2`) and we looked at the sampling distribution of $\bar{X}$ for $n=5$ (`poiexp_samples_5`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# not normal

# %% [markdown]
# u) When our original data came from a non-Normal distribution (`population_2`) and we looked at the sampling distribution of $\bar{X}$ for $n=50$ (`poiexp_samples_50`), what was the shape of the sampling distribution of $\bar{X}$?

# %% [markdown]
# approaching Normal

# %% [markdown]
# v) So, if our original population is not a Normal distribution, what will the sampling distribution be shaped like when $n$ is small (like 5)?

# %% [markdown]
# not normal

# %% [markdown]
# w) So, if our original population is not a Normal distribution, what will the sampling distribution be shaped like when $n$ is large (like 50)?

# %% [markdown]
# approaching normal

# %% [markdown]
# x) When you sample from a non-Normal distribution, what happens to our sampling distribution of $\bar{X}$ as we increase $n$?

# %% [markdown]
# approaches normal

# %% [markdown]
# BONUS: If you're so inclined, repeat steps k and l for sample size $n=10, 20, 30, 50, 100$ to look at this phenomenon more closely! You could write a loop to do this.

# %%
N=[10,20,30,50,100]
for i in N:
  temp=sampler(population_2,i,1000)  
  sns.distplot(temp);
